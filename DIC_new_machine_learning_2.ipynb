# %%
#課題1
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from scipy.stats import zscore
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

boston = load_boston()
X=pd.DataFrame(boston.data[:100,:], columns = boston.feature_names)
y=boston.target[:100]
x=X['LSTAT'].values

lin_1d = LinearRegression()
lin_2d = LinearRegression()
lin_3d = LinearRegression()
lin_4d = LinearRegression()

degree_2 = PolynomialFeatures(degree=2)
degree_3 = PolynomialFeatures(degree=3)
degree_4 = PolynomialFeatures(degree=4)

x_2=degree_2.fit_transform(x[:,None])
x_3=degree_3.fit_transform(x[:,None])
x_4=degree_4.fit_transform(x[:,None])

lin_1d.fit(x[:,None],y)
lin_2d.fit(x_2,y)
lin_3d.fit(x_3,y)
lin_4d.fit(x_4,y)

x_lin=np.linspace(np.min(x[:,None]), np.max([x[:,None]]),1000)
x_lin_2=degree_2.fit_transform(x_lin[:,None])
x_lin_3=degree_3.fit_transform(x_lin[:,None])
x_lin_4=degree_4.fit_transform(x_lin[:,None])

y_1d_fit=lin_1d.predict(x_lin[:,None])
y_2d_fit=lin_2d.predict(x_lin_2)
y_3d_fit=lin_3d.predict(x_lin_3)
y_4d_fit=lin_4d.predict(x_lin_4)

plt.title("Boston House Price")
plt.scatter(x,y,label='data')
plt.plot(x_lin,y_1d_fit,'r',label='1d_lin')
plt.plot(x_lin,y_2d_fit,'g',label='2d_lin')
plt.plot(x_lin,y_3d_fit,'c',label='3d_lin')
plt.plot(x_lin,y_4d_fit,'m',label='4d_lin')
plt.ylim(10, 40)
plt.xlabel("LSTAT")
plt.ylabel("price")
plt.legend()
plt.show()

print("1次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_1d.predict(x[:,None])))
print("2次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_2d.predict(x_2)))
print("3次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_3d.predict(x_3)))
print("4次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_4d.predict(x_4)))

print("以上より、４次関数の場合が２乗和誤差が最も小さくなる。")
# Out:
# 1次関数の場合の２乗和誤差＝ 15.5379060075
# 2次関数の場合の２乗和誤差＝ 10.9202269053
# 3次関数の場合の２乗和誤差＝ 10.0552257097
# 4次関数の場合の２乗和誤差＝ 9.61739071542
# 以上より、４次関数の場合が２乗和誤差が最も小さくなる。

# %%
#課題2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from scipy.stats import zscore
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

boston = load_boston()
X = pd.DataFrame(boston.data[:100,:], columns = boston.feature_names)
y = boston.target[:100]

x = X["AGE"].values

lin_1d = LinearRegression()
lin_2d = LinearRegression()
lin_3d = LinearRegression()
lin_4d = LinearRegression()

degree_2 = PolynomialFeatures(degree = 2)
degree_3 = PolynomialFeatures(degree = 3)
degree_4 = PolynomialFeatures(degree = 4)

x_2 = degree_2.fit_transform(x[:,None])
x_3 = degree_3.fit_transform(x[:,None])
x_4 = degree_4.fit_transform(x[:,None])

lin_1d.fit(x[:,None],y)
lin_2d.fit(x_2,y)
lin_3d.fit(x_3,y)
lin_4d.fit(x_4,y)

x_lin = np.linspace(np.min(x[:,None]),np.max(x[:,None]),100)
x_lin_2 = degree_2.fit_transform(x_lin[:,None])
x_lin_3 = degree_3.fit_transform(x_lin[:,None])
x_lin_4 = degree_4.fit_transform(x_lin[:,None])

plt.title("Boston House Price")
plt.scatter(x,y,label='data')
plt.plot(x_lin,lin_1d.predict(x_lin[:,None]),"r",label='1d_lin')
plt.plot(x_lin,lin_2d.predict(x_lin_2),"g",label='2d_lin')
plt.plot(x_lin,lin_3d.predict(x_lin_3),"c",label='3d_lin')
plt.plot(x_lin,lin_4d.predict(x_lin_4),"m",label='4d_lin')
plt.xlabel("Age")
plt.ylabel("Price")
plt.legend()
plt.show()

print("1次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_1d.predict(x[:,None])))
print("2次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_2d.predict(x_2)))
print("3次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_3d.predict(x_3)))
print("4次関数の場合の２乗和誤差＝",mean_squared_error(y,lin_4d.predict(x_4)))

print("以上より、４次関数の場合が２乗和誤差が最も小さくなる。")
# Out:
# 1次関数の場合の２乗和誤差＝ 26.7545087041
# 2次関数の場合の２乗和誤差＝ 24.3970881365
# 3次関数の場合の２乗和誤差＝ 23.9782421997
# 4次関数の場合の２乗和誤差＝ 23.9568169768
# 以上より、４次関数の場合が２乗和誤差が最も小さくなる。

# %%
#精度計算
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from scipy.stats import zscore
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

boston = load_boston()
X=pd.DataFrame(boston.data[:,:], columns = boston.feature_names)

x=X['LSTAT'].values
y=boston.target[:]

x_train, x_test,y_train,y_test =train_test_split(x,y,train_size = 0.6, random_state=0)

lin_1d = LinearRegression()
lin_2d = LinearRegression()
lin_3d = LinearRegression()
lin_4d = LinearRegression()

degree_2 = PolynomialFeatures(degree = 2)
degree_3 = PolynomialFeatures(degree = 3)
degree_4 = PolynomialFeatures(degree = 4)

x_train_2 = degree_2.fit_transform(x_train[:,None])
x_train_3 = degree_3.fit_transform(x_train[:,None])
x_train_4 = degree_4.fit_transform(x_train[:,None])

lin_1d.fit(x_train[:,None],y_train)
lin_2d.fit(x_train_2,y_train)
lin_3d.fit(x_train_3,y_train)
lin_4d.fit(x_train_4,y_train)

x_test_2 = degree_2.fit_transform(x_test[:,None])
x_test_3 = degree_3.fit_transform(x_test[:,None])
x_test_4 = degree_4.fit_transform(x_test[:,None])

y_1_predict = lin_1d.predict(x_test[:,None])
y_2_predict = lin_2d.predict(x_test_2)
y_3_predict = lin_3d.predict(x_test_3)
y_4_predict = lin_4d.predict(x_test_4)


score_1d = lin_1d.score(x_test[:,None],y_test)
score_2d = lin_2d.score(x_test_2 ,y_test)
score_3d = lin_3d.score(x_test_3,y_test)
score_4d = lin_4d.score(x_test_4 ,y_test)

print("１次関数の場合は精度%.2f"%(score_1d) )
print("2次関数の場合は精度%.2f"%(score_2d) )
print("3次関数の場合は精度%.2f"%(score_3d) )
print("4次関数の場合は精度%.2f"%(score_4d) )
# Out:
# １次関数の場合は精度0.52
# 2次関数の場合は精度0.60
# 3次関数の場合は精度0.62
# 4次関数の場合は精度0.64

# %%
#重回帰分析
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from scipy.stats import zscore
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

def standard_scalar(data):
    sc = StandardScaler()
    sc.fit(data)
    sc_data = sc.transform(data)
    return sc_data

boston = load_boston()
X=pd.DataFrame(boston.data[:,:], columns = boston.feature_names)
y=boston.target[:]

x=pd.DataFrame()
x['LSTAT']=X['LSTAT'].values
x['RM']=X['RM'].values
x['AGE']=X['AGE'].values

x = standard_scalar(x)

x_train, x_test,y_train,y_test =train_test_split(x,y,train_size = 0.6, random_state=0)

lin_1d = LinearRegression()
lin_2d = LinearRegression()
lin_3d = LinearRegression()
lin_4d = LinearRegression()

x_train_2 = degree_2.fit_transform(x_train)
x_train_3 = degree_3.fit_transform(x_train)
x_train_4 = degree_4.fit_transform(x_train)

lin_1d.fit(x_train,y_train)
lin_2d.fit(x_train_2,y_train)
lin_3d.fit(x_train_3,y_train)
lin_4d.fit(x_train_4,y_train)

x_test_2 = degree_2.fit_transform(x_test)
x_test_3 = degree_3.fit_transform(x_test)
x_test_4 = degree_4.fit_transform(x_test)

y_1_predict = lin_1d.predict(x_test)
y_2_predict = lin_2d.predict(x_test_2)
y_3_predict = lin_3d.predict(x_test_3)
y_4_predict = lin_4d.predict(x_test_4)


score_1d = lin_1d.score(x_test,y_test)
score_2d = lin_2d.score(x_test_2 ,y_test)
score_3d = lin_3d.score(x_test_3,y_test)
score_4d = lin_4d.score(x_test_4 ,y_test)

print("１次関数の場合は精度%.2f"%(score_1d) )
print("2次関数の場合は精度%.2f"%(score_2d) )
print("3次関数の場合は精度%.2f"%(score_3d) )
print("4次関数の場合は精度%.2f"%(score_4d) )
# Out:
# １次関数の場合は精度0.63
# 2次関数の場合は精度0.75
# 3次関数の場合は精度0.74
# 4次関数の場合は精度0.63
