# %% [raw]
# #線形回帰とは何か
# 線形回帰とは何か。
# →複数の変数の相関を直線モデルによって求める手法
# 具体的に言うと？
# →CPUの性能、SSDの容量、液晶サイズ、液晶解像度などからパソコンの価格を予測する。
# 分類と何か違うのか。
# →分類はクラスに分けること、回帰は予測すること

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
# %matplotlib inline
#データを取得する
#取得データをDataFrameにする
X_original = pd.DataFrame(load_boston().data,columns=load_boston().feature_names)
y = pd.DataFrame(load_boston().target)
y.columns = ['PRICE']

#説明変数を'LSTAT'のみにする
X = pd.DataFrame(X_original["LSTAT"])

# %% [raw]
# 単回帰と重回帰についての違いを記述せよ
# →目的変数に関して１つの説明変数のみ相関があるとした回帰を単回帰、複数の説明関数が相関があるとした回帰を重回帰と呼ぶ。

# %%
#テストデータに分割する
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
#学習
lin_1d = LinearRegression()
lin_1d.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#決定係数
score_1d = lin_1d.score(X_test,y_test)
print("一次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_1d))
# Out:
# 一次式における'LSTAT'の住宅価格への決定係数は0.43

# %% [raw]
# #決定係数とは何か記述せよ
# 決定係数とは何か
# →回帰分析によって求められた目的変数の予測値が、実際の目的変数の値とどの程度あっているかを表した数値。１に近づくほどあっている。
# もっとも説明変数が、目的変数を説明できる場合、決定係数は何になるか
# →１
# どのように求めることができるか
# →回帰変動を全変動で割ることで求まる。

# %% [raw]
# ＃定係数をいかなる場合も信じても良いか記述せよ
# 決定係数が正しく評価できない例を答えよ
# →極端に数の少ないテストデータに対して高い決定係数が得られた回帰モデルが数の多いテストデータで同じく高い決定係数が得られるとは限らない。

# %%
#2,3,4次式の回帰
lin_2d = LinearRegression()
lin_3d = LinearRegression()
lin_4d = LinearRegression()

degree_2 = PolynomialFeatures(degree = 2)
degree_3 = PolynomialFeatures(degree = 3)
degree_4 = PolynomialFeatures(degree = 4)

x_train_2 = degree_2.fit_transform(X_train)
x_train_3 = degree_3.fit_transform(X_train)
x_train_4 = degree_4.fit_transform(X_train)

lin_2d.fit(x_train_2,y_train)
lin_3d.fit(x_train_3,y_train)
lin_4d.fit(x_train_4,y_train)

x_test_2 = degree_2.fit_transform(X_test)
x_test_3 = degree_3.fit_transform(X_test)
x_test_4 = degree_4.fit_transform(X_test)

score_2d = lin_2d.score(x_test_2 ,y_test)
score_3d = lin_3d.score(x_test_3,y_test)
score_4d = lin_4d.score(x_test_4 ,y_test)

print("二次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_2d))
print("三次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_3d))
print("四次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_4d))
# Out:
# 二次式における'LSTAT'の住宅価格への決定係数は0.52
# 三次式における'LSTAT'の住宅価格への決定係数は0.54
# 四次式における'LSTAT'の住宅価格への決定係数は0.57

# %% [raw]
# #次数が大きくなるとどうなるか記述せよ
# 説明変数をxとして、次数を増やしていくとどのように数式が変化していくか記述せよ（1次式 ax + b）
# →ax^2+bx+c(二次式）、ax^3+bx^2+cx+d
# 次数を増やすとどのようなメリットが考えられるか
# →よりトレーニングデータにフィットした曲線が得られる。
# 次数を増やすとどのようなデメリットが考えられるか
# →過学習が起こりやすくなる。

# %%
#重回帰
boston = pd.concat([X_original,y],axis=1)
boston.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
X２ = pd.DataFrame(X_original[["RM","LSTAT","PTRATIO"]])
def standard_scalar(data):
    sc = StandardScaler()
    sc.fit(data)
    sc_data = sc.transform(data)
    return sc_data

X2 = pd.DataFrame(standard_scalar(X2),columns=["RM","LSTAT","PTRATIO"])
X2_train, X2_test, y2_train, y2_test = train_test_split(X2,y,test_size=0.2)

lin_1d = LinearRegression()
lin_2d = LinearRegression()
lin_3d = LinearRegression()
lin_4d = LinearRegression()
lin_5d = LinearRegression()


degree_2 = PolynomialFeatures(degree = 2)
degree_3 = PolynomialFeatures(degree = 3)
degree_4 = PolynomialFeatures(degree = 4)
degree_5 = PolynomialFeatures(degree = 5)

x2_train_2 = degree_2.fit_transform(X2_train)
x2_train_3 = degree_3.fit_transform(X2_train)
x2_train_4 = degree_4.fit_transform(X2_train)
x2_train_5 = degree_5.fit_transform(X2_train)

lin_1d.fit(X2_train,y2_train)
lin_2d.fit(x2_train_2,y2_train)
lin_3d.fit(x2_train_3,y2_train)
lin_4d.fit(x2_train_4,y2_train)
lin_5d.fit(x2_train_5,y2_train)

x2_test_2 = degree_2.fit_transform(X2_test)
x2_test_3 = degree_3.fit_transform(X2_test)
x2_test_4 = degree_4.fit_transform(X2_test)
x2_test_5 = degree_5.fit_transform(X2_test)

score_1d = lin_1d.score(X2_test,y2_test)
score_2d = lin_2d.score(x2_test_2 ,y2_test)
score_3d = lin_3d.score(x2_test_3,y2_test)
score_4d = lin_4d.score(x2_test_4 ,y2_test)
score_5d = lin_5d.score(x2_test_5 ,y2_test)

print("一次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_1d))
print("二次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_2d))
print("三次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_3d))
print("四次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_4d))
print("五次式における'LSTAT'の住宅価格への決定係数は%.2f"%(score_5d))
# Out:
# 一次式における'LSTAT'の住宅価格への決定係数は0.63
# 二次式における'LSTAT'の住宅価格への決定係数は0.79
# 三次式における'LSTAT'の住宅価格への決定係数は0.78
# 四次式における'LSTAT'の住宅価格への決定係数は-2.11
# 五次式における'LSTAT'の住宅価格への決定係数は0.50

# %% [raw]
# #重回帰について記述せよ
# 説明変数を増やすことでどのようなメリットがあるか
# →説明変数同士の相関がなく目的変数との相関が高い場合、それら説明変数の効果を取り入れ予測制度を向上できる可能性がある。
#
# 説明変数を増やすことでどのようなデメリットがあるか
# →説明力向上に関係しない説明変数を追加した場合でも決定係数が上がる場合がある。
# 　　　　よって未知のデータに関して精度が高くなるかはわからない。
#   　　説明変数同士の相関がない事を確認する必要がある。
